# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
result = np.load("plane_result.npy")

# %%
plt.imshow(result)

# %%
planeresult=np.transpose(result,[1,0])

# %%
plane=np.zeros((664,1641))
for i in range(664):
    plane[663-i] = planeresult[i]

# %%
if 5/0.000001 == np.nan:
    print("nan")

# %%
import math
for i in range(664):
    for j in range(1641):
        if math.isnan(plane[i,j]):
            print("nan")

# %%
fig = plt.figure(2,figsize=(30,10))
#colormap = plt.cm.cmapname          
plt.imshow(plane[:,:1620])#,cmap=colormap)
plt.colorbar()
#plt.savefig("plane_result.png", dpi=1000)

# %%
import time

# %%
data = np.load(file="pred_lines_850_791.npy")

# %%
data.shape
# Out:
# (1641, 664, 1251)

# %%
fig = plt.figure(2,figsize=(30,10))
#colormap = plt.cm.cmapname
plt.imshow(data[1630,:,:])#,vmin=0,vmax=1),cmap=colormap
plt.colorbar()
#plt.savefig("plane_result.png", dpi=1000)

# %%
fig = plt.figure(2,figsize=(30,10))
#colormap = plt.cm.viridis
plt.imshow(data[1620,:,:])#,cmap=colormap)

# %%
data[1630,:,200]
# Out:
# array([ 0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
#         0.36495376,  0.36495376,  0.36495376,  0.36495376,  0.36495376,
# ...
