# %%
import numpy as np

# %%
data = np.load("plane_data.npy")

# %%
data[0,:]
# Out:
# array([  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00,
#         -2.44750047e+00,  -2.45681763e+00,  -2.13521266e+00,
#         -5.84935490e-03,  -4.49670733e-05,   2.74392823e-05,
#          3.27863870e-03,   4.09284607e-03,   3.43541149e-03,
#          2.10426189e-03,   2.64804345e-03,   3.68781807e-03,
#          9.63833928e-03,   6.42247545e-03,   7.56910909e-03,
#          8.09234660e-03,   9.45374183e-03,  -2.70653842e-03,
#         -7.07071391e-04,  -4.61399043e-03,   5.09618828e-03,
#          3.44519364e-03,   4.25067637e-03,   1.83854674e-04,
#          4.91484208e-03,   9.62500274e-03,   4.28842492e-02,
#          1.24517800e-02,  -6.62116148e-03,   1.09457038e-03,
#          9.82561382e-04,  -3.93464509e-03,  -4.97655990e-03,
#          1.78087282e+00,   1.87526572e+00,   1.84970093e+00,
#          1.69624400e+00,  -7.86518794e-04,  -7.85711629e-04,
#         -2.04292577e-04,  -1.44735450e-05,  -1.99889660e+00,
# ...

# %%
import numpy as np

# %%
data = np.load("plane_data.npy")

# %%
data.shape
# Out:
# (1089624, 76)

# %%
plane = np.reshape(data,(664,1641,76))

# %%
plane.shape
# Out:
# (664, 1641, 76)

# %%
plane[663,:,:]
# Out:
# array([[  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        [  1.89679731e+09,   1.71146740e+12,   4.48912884e+11, ...,
#           1.71135280e+07,   1.54083900e+07,   3.12759300e+07],
#        [  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        ...,
#        [  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        [  1.91223808e+09,   1.73055096e+12,   4.54073057e+11, ...,
#           1.71528520e+07,   1.54437970e+07,   3.13478260e+07],
#        [  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00]], dtype=float32)

# %%
plane[0,:,:]
# Out:
# array([[ 0.0405651 , -1.52432668, -2.11544776, ..., -2.96466494,
#         -2.49846911, -2.07975721],
#        [ 0.0405651 , -1.52432668, -2.11544776, ..., -2.96466494,
#         -2.49846911, -2.07975721],
#        [ 0.0405651 , -1.52432668, -2.11544776, ..., -2.96466494,
#         -2.49846911, -2.07975721],
#        ...,
#        [ 0.61895573, -0.2332399 , -1.18467188, ..., -0.78756219,
#         -0.25360772, -0.22861238],
#        [ 0.46022913, -0.09467495, -1.19545949, ..., -1.35971987,
#         -0.87489265, -0.40615228],
#        [ 0.47270975, -0.39970013, -0.51242232, ..., -1.57279527,
#         -0.98145664, -0.39240539]], dtype=float32)

# %%
plane[0,:50]
# Out:
# array([[  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        [  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        [  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        ...,
#        [  1.59178126e+00,   2.74956093e+01,   5.49374533e+00, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        [  8.33124466e+01,   1.55631433e+03,   4.06358765e+02, ...,
#          -2.96466494e+00,  -2.49846911e+00,  -2.07975721e+00],
#        [  4.05650958e-02,  -1.52432668e+00,  -2.11544776e+00, ...,
#                      nan,              nan,              nan]], dtype=float32)

# %%
plane[0,1620:1640,0]
# Out:
# array([-0.52622366,  0.27671343,  0.43525681,  0.58065498,  0.64158809,
#         0.70177275,  0.64188576,  0.71106768, -0.57527703, -0.5357489 ,
#         0.65854824,  0.61479229, -0.50272775,  0.65241897,  0.62306267,
#         0.68780231,  0.67924637, -0.22470598,  0.61895573,  0.46022913], dtype=float32)

# %%
plane[0,:30,0]
# Out:
# array([  4.05650958e-02,   4.05650958e-02,   4.05650958e-02,
#          4.05650958e-02,   4.05650958e-02,   4.05650958e-02,
#          4.05650958e-02,   4.05650958e-02,   4.05650958e-02,
#          4.05650958e-02,   2.89091606e+01,              nan,
#          4.05650958e-02,              nan,   4.05650958e-02,
#          9.82419440e+07,              nan,   4.05650958e-02,
#                     nan,   4.05650958e-02,   2.04573281e+05,
#          4.05650958e-02,              nan,              nan,
#                     nan,   4.05650958e-02,   4.05650958e-02,
#          4.05650958e-02,   3.65281403e-01,   4.05651294e-02], dtype=float32)
